# %% [markdown]
# <h1 style="font-size:50px; text-align:center; padding:15px;">
#     Deep Learning Tutorial - Segmentation of Brain MR Images
# </h1>

# %% [markdown]
# In this tutorial, we will explore how **deep learning models**, particularly the **U-Net architecture**, can be applied to **automatically** segment brain tumors, from MR images.

# %% [markdown]
# Over the last decade, deep learning has revolutionized numerous fields, including **medical imaging**. These Deep learning solutions are increasingly being integrated into patient care, allieviating the workload of medical professionals and enhancing diagnostic accuracy.
#
# One standout application is **automatic segmentation** which has become mainstream in medical diagnostics and treatment planning. **Manual contouring** is not only **time consuming** but also **highly subjective**, leading to **inter-observer variability**—differences in segmentation results between radiologists.
#
# An objective delianation of the tumor by use of a AI model with soTA performance makes the longitudinal assessment of **tumor progression** and its **response to treatment** much more **robust**.

# %% [markdown]
# <h1 style="font-size:25px; padding:5px;">
#    But What is segmentation ?
# </h1>

# %% [markdown]
# Segmentation is a key task in medical image analysis, where an image is divided into meaningful regions, typically to identify structures like **organs**, or **tumors**. In **brain tumor segmentation**, the goal is to separate the tumor from healthy brain tissue in MRI scans.
#
# Unlike **classification** (which labels an entire image), or **detection** (which identifies object locations), segmentation provides a **pixel-wise mask**, which is crucial for treatment planning, and disease monitoring.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="resources/classification%20vs%20detection%20vs%20segmentation.jpeg" alt="Classification vs Detection vs Segmentation" width="800px">
# </div>

# %% [markdown]
# In image segmentation, a deep learning model learns to classify each pixel in an image as belonging to a specific category :

# %% [markdown]
# <div style="text-align: center;">
#     <img src="resources/segmentation.png" alt="Classification vs Detection vs Segmentation" width="800px">
# </div>

# %% [markdown]
# <h1 style="font-size:25px; padding:5px;">
# The BraTS Challenge: Brain Tumor Segmentation Benchmark 🧠🎯
# </h1>

# %% [markdown]
# The **Brain Tumor Segmentation (BraTS) Challenge** is an international competition designed to advance the development of **automated brain tumor segmentation models**. It provides researchers with standardized datasets and evaluation metrics to compare different deep-learning approaches.
#
# the labels L1, L2, and L4 refer to different types of tumor structures annotated in the MRI scans. Specifically:
#
# - **L1 (NCR/NET - Necrotic and Non-Enhancing Tumor Core)** : Represents the necrotic (dead) tumor core and the non-enhancing tumor regions.
#
# - **L2 (ED - Peritumoral Edema)** : Represents peritumoral edema, which is swelling around the tumor due to fluid accumulation.
# It often surrounds the tumor and appears as hyperintense regions in FLAIR sequences.
# - **L4 (ET - Enhancing Tumor)** : Represents the enhancing tumor region, which is the actively growing part of the tumor.
# It appears as a bright region in contrast-enhanced MRI (T1ce) scans.

# %% [markdown]
# <div style="text-align: center;">
#     <img src="resources/BRats.png" alt="two different subjects from the BraTS dataset" width="800px">
# </div>

# %% [markdown]
# ## 🧠 Exercise 0: Visualizing a BraTS Patient's MRI Scans

# %% [markdown]
# - Load **multi-modal MRI scans** (T1, T1gd, T2, FLAIR) from a BraTS patient in the folder (example BraTS patients).
# - Extract an **axial-slice** (middle cross section).
# - Visualize different **MRI sequences side by side** along with the slice's corresponding mask

# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# Patient name : 
patient_name = "BraTS19_CBICA_AAG_1"

# Paths to MRI scans and the masks data : 
dict_mri_paths = {
    imaging: fr"example BraTS patients/{patient_name}/{patient_name}_{imaging}.nii.gz" 
    for imaging in ["t1", "t1ce", "t2", "flair"]
}

path_seg = fr"example BraTS patients/{patient_name}/{patient_name}_seg.nii.gz"     # mask file

# Load the images using nibabel : 
dict_mri_images = {
    imaging: nib.load(dict_mri_paths[imaging]).get_fdata()
    for imaging in ["t1", "t1ce", "t2", "flair"]
}

img_seg = nib.load(path_seg).get_fdata()

# the Slice Index : 
slice_idx = 55  # Extracting the middle axial slice

# %%
# Plot the MRI slices and the Labels data : 
fig, axes = plt.subplots(1, 5, figsize=(18, 4))

for i, imaging in enumerate(["t1", "t1ce", "t2", "flair"]):

    axes[i].imshow(dict_mri_images[imaging][:, :, slice_idx].T, cmap="gray")
    axes[i].set_title(imaging.upper())

axes[4].imshow(img_seg[:, :, slice_idx].T, cmap="gray")
axes[4].set_title("Labels")

plt.suptitle("BraTS MRI Modalities - Axial View", fontsize=15)
plt.show()

# %%
# Plot the MRI slices with the Labels overlayed on the mri image : 
fig, axes = plt.subplots(1, 4, figsize=(16, 4))

for i, imaging in enumerate(["t1", "t1ce", "t2", "flair"]):

    axes[i].imshow(dict_mri_images[imaging][:, :, slice_idx].T, cmap="gray")
    axes[i].imshow(img_seg[:, :, slice_idx].T, cmap="jet", alpha=0.2)
    axes[i].set_title(imaging.upper())

plt.suptitle("BraTS MRI Modalities - Axial View", fontsize=15)
plt.show()

# %% [markdown]
# In this tutorial, we'll simplify the BraTS challenge, as we will attempt to predict the **L4 (ET - Enhancing Tumor)** based on the T1CE imaging, using the U-Net architecture :

# %% [markdown]
# <h1 style="font-size:15px; padding:5px;">
#    Dataset Details
# </h1>

# %% [markdown]
# The dataset used in this tutorial consists of T1CE MRI brain scans from 335 patients.
#
# - Each patient has multiple **2D slices** extracted from their **3D T1CE MRI scan**.
#
# - The naming convention (patient_XXX_YYYY.nii.gz) indicates:
#     - **XXX** → Patient ID
#     - **YYYY** → Slice number within that patient’s scan.
#
#
#
# The dataset is organized into two main folders :
#
# - **Train** - Contains images and corresponding segmentation masks from **284** patients, for training the deep learning model.
# - **Test**  - Contains images and segmentation masks from **51** patients, for evaluating the model after training
#
# Each subset is further divided into:
#
# - Images: Contains 2D slices of the brain MRI scans.
#
# - Masks: Contains the corresponding binary segmentation masks, where:
#     - 1 (White) represents the enhancing tumor region .
#     - 0 (Black) represents all tissue that is not enhancing tumor .
#
# ├── data
#
#     ├── train
#     │   ├── images
#     │   │   ├── patient_001_0001.nii.gz
#     │   │   ├── patient_001_0002.nii.gz
#     │   │   ├── ...
#     │   ├── masks
#     │   │   ├── patient_001_0001.nii.gz
#     │   │   ├── patient_001_0002.nii.gz
#     │   │   ├── ...
#     ├── test
#     │   ├── images
#     │   │   ├── patient_251_0001.nii.gz
#     │   │   ├── patient_251_0002.nii.gz
#     │   │   ├── ...
#     │   ├── masks
#     │   │   ├── patient_251_0001.nii.gz
#     │   │   ├── patient_251_0002.nii.gz
#     │   │   ├── ...

# %% [markdown]
# <h1 style="font-size:15px; padding:5px;">
#    U-Net Architecture
# </h1>

# %% [markdown]
# By the end of this tutorial, you will:
#
#     - Learn about the U-Net architecture
#     - Implement a U-Net architecture in python using PyTorch
#     - Train and evaluate the segmentation performance using relevant metrics

# %% [markdown]
# ## 🧠 Exercise 1: Split the train dataset into training images and validation images :

# %% [markdown]
# When training a deep learning model, our goal is to create a model that performs well not just on the training data, but also on unseen data (test set).
#
# If we only evaluate performance on the training set, we risk **overfitting**, where the model memorizes the training data instead of learning meaningful patterns.
#
# To ensure our deep learning model generalizes well to new, unseen data, we need to split our training dataset into two subsets:
#
# - **Training Set**  – Used to train the model.
# - **Validation Set**  – Used to evaluate model performance during **training** .
#
# We will implement a **Patient-based Splitting** to ensure that all slices from a single patient belong **only to either training or validation**, not both :

# %%
from sklearn.model_selection import train_test_split
import random
import os


# List of slice names for both training and test : 
list_original_train_slices = os.listdir("data/train/images")
list_test_slices = os.listdir("data/test/images")

# Extract patients IDs that correspond to the training set : 
list_original_train_ids = list(set(
    [slice_name.split("_")[1] for slice_name in list_original_train_slices]
))

# Split the training patients into training and validation sets (e.g., 80%, 20%)
# random_state=42 ensures that the split is always the same. This is useful for reproducibility.
list_train_ids, list_val_ids = train_test_split(list_original_train_ids, test_size=0.2, random_state=42)

list_train_slices = [slice_name for slice_name
                     in list_original_train_slices
                     if slice_name.split("_")[1] in list_train_ids]

list_val_slices = [slice_name for slice_name
                   in list_original_train_slices
                   if slice_name.split("_")[1] in list_val_ids]

print(fr"Number of slices in the training set : {len(list_train_slices)}")
print(fr"Number of slices in the validation set : {len(list_val_slices)}")
print(fr"Number of slices in the testing set : {len(list_test_slices)}")
# Out:
# Number of slices in the training set : 31974
# Number of slices in the validation set : 8029
# Number of slices in the testing set : 7225

# %% [markdown]
# ## 🧠 Exercise 2: Build a U-Net model :

# %% [markdown]
# <div style="text-align: center;">
#     <img src="resources/modele unet.png" alt="U-Net model" width="800px">
# </div>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class UNet(nn.Module):
    def __init__(self, in_channels=1, out_channels=1):
        super(UNet, self).__init__()

        # Encoder (Downsampling)
        self.enc1 = self.conv_block(in_channels, 32)
        self.enc2 = self.conv_block(32, 64)
        self.enc3 = self.conv_block(64, 128)
        self.enc4 = self.conv_block(128, 256)
        self.enc5 = self.conv_block(256, 320)

        # Bottleneck
        self.bottleneck = self.conv_block(320, 320)

        # Decoder (Upsampling)
        self.up1 = nn.ConvTranspose2d(320, 256, kernel_size=2, stride=2)
        self.dec1 = self.conv_block(512, 256)  # (256+256=512)

        self.up2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.dec2 = self.conv_block(256, 128)  # (128+128=256)

        self.up3 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.dec3 = self.conv_block(128, 64)  # (64+64=128)

        self.up4 = nn.ConvTranspose2d(64, 32, kernel_size=2, stride=2)
        self.dec4 = self.conv_block(64, 32)  # (32+32=64)

        # Output layer
        self.out = nn.Conv2d(32, out_channels, kernel_size=1)

        # MaxPooling
        self.maxpool = nn.MaxPool2d(kernel_size=2, stride=2)

    def forward(self, x):
        # Encoding Path
        x1 = self.enc1(x)
        x2 = self.enc2(self.maxpool(x1))
        x3 = self.enc3(self.maxpool(x2))
        x4 = self.enc4(self.maxpool(x3))
        x5 = self.enc5(self.maxpool(x4))

        # Bottleneck
        x = self.bottleneck(x5)

        # Decoding Path
        x = self.up1(x)
        x = torch.cat((x, x4), dim=1)  # (256+256=512)
        x = self.dec1(x)

        x = self.up2(x)
        x = torch.cat((x, x3), dim=1)  # (128+128=256)
        x = self.dec2(x)

        x = self.up3(x)
        x = torch.cat((x, x2), dim=1)  # (64+64=128)
        x = self.dec3(x)

        x = self.up4(x)
        x = torch.cat((x, x1), dim=1)  # (32+32=64)
        x = self.dec4(x)

        # Output Layer: Return raw logits (do not apply sigmoid here)
        return self.out(x)

    def conv_block(self, in_channels, out_channels):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),  # Optional: Batch Norm for stability
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),  # Optional: Batch Norm for stability
            nn.ReLU(inplace=True)
        )

# %%
# Create U-Net model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = UNet(in_channels=1, out_channels=1).to(device)

# %%
# Print Model Summary
from torchsummary import summary
summary(model, input_size=(1, 240, 240))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 240, 240]             320
#        BatchNorm2d-2         [-1, 32, 240, 240]              64
#               ReLU-3         [-1, 32, 240, 240]               0
#             Conv2d-4         [-1, 32, 240, 240]           9,248
#        BatchNorm2d-5         [-1, 32, 240, 240]              64
#               ReLU-6         [-1, 32, 240, 240]               0
#          MaxPool2d-7         [-1, 32, 120, 120]               0
#             Conv2d-8         [-1, 64, 120, 120]          18,496
#        BatchNorm2d-9         [-1, 64, 120, 120]             128
#              ReLU-10         [-1, 64, 120, 120]               0
#            Conv2d-11         [-1, 64, 120, 120]          36,928
#       BatchNorm2d-12         [-1, 64, 120, 120]             128
#              ReLU-13         [-1, 64, 120, 120]               0
#         MaxPool2d-14           [-1, 64, 60, 60]               0
#            Conv2d-15          [-1, 128, 60, 60]          73,856
#       BatchNorm2d-16          [-1, 128, 60, 60]             256
#              ReLU-17          [-1, 128, 60, 60]               0
#            Conv2d-18          [-1, 128, 60, 60]         147,584
#       BatchNorm2d-19          [-1, 128, 60, 60]             256
#              ReLU-20          [-1, 128, 60, 60]               0
#         MaxPool2d-21          [-1, 128, 30, 30]               0
#            Conv2d-22          [-1, 256, 30, 30]         295,168
#       BatchNorm2d-23          [-1, 256, 30, 30]             512
#              ReLU-24          [-1, 256, 30, 30]               0
#            Conv2d-25          [-1, 256, 30, 30]         590,080
#       BatchNorm2d-26          [-1, 256, 30, 30]             512
#              ReLU-27          [-1, 256, 30, 30]               0
#         MaxPool2d-28          [-1, 256, 15, 15]               0
#            Conv2d-29          [-1, 320, 15, 15]         737,600
#       BatchNorm2d-30          [-1, 320, 15, 15]             640
#              ReLU-31          [-1, 320, 15, 15]               0
#            Conv2d-32          [-1, 320, 15, 15]         921,920
#       BatchNorm2d-33          [-1, 320, 15, 15]             640
#              ReLU-34          [-1, 320, 15, 15]               0
#            Conv2d-35          [-1, 320, 15, 15]         921,920
#       BatchNorm2d-36          [-1, 320, 15, 15]             640
#              ReLU-37          [-1, 320, 15, 15]               0
#            Conv2d-38          [-1, 320, 15, 15]         921,920
#       BatchNorm2d-39          [-1, 320, 15, 15]             640
#              ReLU-40          [-1, 320, 15, 15]               0
#   ConvTranspose2d-41          [-1, 256, 30, 30]         327,936
#            Conv2d-42          [-1, 256, 30, 30]       1,179,904
#       BatchNorm2d-43          [-1, 256, 30, 30]             512
#              ReLU-44          [-1, 256, 30, 30]               0
#            Conv2d-45          [-1, 256, 30, 30]         590,080
#       BatchNorm2d-46          [-1, 256, 30, 30]             512
#              ReLU-47          [-1, 256, 30, 30]               0
#   ConvTranspose2d-48          [-1, 128, 60, 60]         131,200
#            Conv2d-49          [-1, 128, 60, 60]         295,040
#       BatchNorm2d-50          [-1, 128, 60, 60]             256
#              ReLU-51          [-1, 128, 60, 60]               0
#            Conv2d-52          [-1, 128, 60, 60]         147,584
#       BatchNorm2d-53          [-1, 128, 60, 60]             256
#              ReLU-54          [-1, 128, 60, 60]               0
#   ConvTranspose2d-55         [-1, 64, 120, 120]          32,832
#            Conv2d-56         [-1, 64, 120, 120]          73,792
#       BatchNorm2d-57         [-1, 64, 120, 120]             128
#              ReLU-58         [-1, 64, 120, 120]               0
#            Conv2d-59         [-1, 64, 120, 120]          36,928
#       BatchNorm2d-60         [-1, 64, 120, 120]             128
#              ReLU-61         [-1, 64, 120, 120]               0
#   ConvTranspose2d-62         [-1, 32, 240, 240]           8,224
#            Conv2d-63         [-1, 32, 240, 240]          18,464
#       BatchNorm2d-64         [-1, 32, 240, 240]              64
#              ReLU-65         [-1, 32, 240, 240]               0
#            Conv2d-66         [-1, 32, 240, 240]           9,248
#       BatchNorm2d-67         [-1, 32, 240, 240]              64
#              ReLU-68         [-1, 32, 240, 240]               0
#            Conv2d-69          [-1, 1, 240, 240]              33
# ================================================================
# Total params: 7,532,705
# Trainable params: 7,532,705
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.22
# Forward/backward pass size (MB): 356.40
# Params size (MB): 28.73
# Estimated Total Size (MB): 385.35
# ----------------------------------------------------------------

# %%
import torch.optim as optim

# Define the loss function
criterion = nn.BCEWithLogitsLoss()

# Define the optimizer
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
import os
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import nibabel as nib
import albumentations as A

class BratsDataset(Dataset):
    def __init__(self, dir_data, list_slices, transform=None):

        self.dir_data = dir_data
        self.list_slices = list_slices
        self.transform= transform

    def __len__(self):
        return len(self.list_slices)

    def __getitem__(self, idx):
        slice_filename = self.list_slices[idx]
        path_image = os.path.join(self.dir_data, "images", slice_filename)
        path_mask = os.path.join(self.dir_data, "masks", slice_filename) 

        # Load the NIfTI files
        image_nii = nib.load(path_image)
        image_data = image_nii.get_fdata().astype(np.float32)  

        mask_nii = nib.load(path_mask)
        mask_data = mask_nii.get_fdata().astype(np.float32)    

        # Add a channel dimension: shape becomes [1, H, W]
        image_data = np.expand_dims(image_data, axis=0)
        mask_data = np.expand_dims(mask_data, axis=0)

        # Convert the NumPy arrays to PyTorch tensors
        image_tensor = torch.tensor(image_data, dtype=torch.float32)
        mask_tensor = torch.tensor(mask_data, dtype=torch.float32)

        # Optionally, apply any additional transforms (these transforms should work on tensors)
        if self.transform:
            augmented = self.transform(image=image_data, mask=mask_data)
            image_data = augmented['image']
            mask_data = augmented['mask']

        # Since the mask is already binary, no additional thresholding is necessary.
        return {
            "slice_name": slice_filename.removesuffix(".nii.gz"),
            "image": image_tensor,
            "mask": mask_tensor
        }

# %%
dir_train = "data/train"  

train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5)
])

# %%
# Visualize data augmentation 

## Load an a slice from a patient as an example : 
example = "patient_001_0100.nii.gz"
path_image, path_mask = f"data/train/images/{example}", f"data/train/masks/{example}"
image_nii, mask_nii = nib.load(path_image), nib.load(path_mask)
image = image_nii.get_fdata().astype(np.float32)  
mask = mask_nii.get_fdata().astype(np.float32)  


# Define individual transformations with p=1.0 for visualization
hflip = A.HorizontalFlip(p=1.0)      # Always flip horizontally
vflip = A.VerticalFlip(p=1.0)        # Always flip vertically
rotate90 = A.RandomRotate90(p=1.0)     # Always rotate by a multiple of 90 degrees

# # Apply each transformation individually
hflip_aug = hflip(image=image, mask=mask)
img_hflip, mask_hflip = hflip_aug["image"], hflip_aug["mask"]

vflip_aug = vflip(image=image, mask=mask)
img_vflip, mask_vflip = vflip_aug["image"], vflip_aug["mask"] 

rotate90_aug = rotate90(image=image, mask=mask)
img_rotate90, mask_rotate90 = rotate90_aug["image"], rotate90_aug["mask"] 

# Apply the composed pipeline (output will vary because of randomness)
pipeline_aug = train_transform(image=image, mask=mask)
img_pipeline, mask_pipeline = pipeline_aug["image"], pipeline_aug["mask"] 

# Visualize the results with overlayed masks
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()

axes[0].imshow(image.T, cmap="gray")
axes[0].imshow(mask.T, cmap="jet", alpha=0.5)
axes[0].set_title("Original Image")

axes[1].imshow(img_hflip.T, cmap="gray")
axes[1].imshow(mask_hflip.T, cmap="jet", alpha=0.5)
axes[1].set_title("Horizontal Flip (p=1.0)")

axes[2].imshow(img_vflip.T, cmap="gray")
axes[2].imshow(mask_vflip.T, cmap="jet", alpha=0.5)
axes[2].set_title("Vertical Flip (p=1.0)")

axes[3].imshow(img_rotate90.T, cmap="gray")
axes[3].imshow(mask_rotate90.T, cmap="jet", alpha=0.5)
axes[3].set_title("Random Rotate90 (p=1.0)")

axes[4].imshow(img_pipeline.T, cmap="gray")
axes[4].imshow(mask_pipeline.T, cmap="jet", alpha=0.5)
axes[4].set_title("Pipeline Output (p=0.5)")

# Hide the unused subplot
axes[5].axis("off")

plt.tight_layout()
plt.show()

# %%
# Create dataset instances
train_dataset = BratsDataset(
    dir_data = dir_train,
    list_slices=list_train_slices, 
    transform=train_transform
)

val_dataset = BratsDataset(
    dir_data = dir_train,
    list_slices=list_val_slices,  
    transform=None
)

# %%
# Create DataLoader objects
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=0)
val_dataloader = DataLoader(val_dataset, batch_size=16, shuffle=False, num_workers=0)

# %%
import tqdm as tqdm

num_epochs = 1

# Placeholders for loss history
train_loss_history = []
val_loss_history = []

# Initialize best validation loss with a large number
best_val_loss = float('inf')

for epoch in range(num_epochs):
    # --------------------------
    # Training Phase
    # --------------------------
    model.train()  # Set model to training mode
    train_losses = []
    
    with tqdm.tqdm(total=len(train_dataloader), desc=f"Epoch {epoch + 1}/{num_epochs}", unit="batch") as pbar:
        
        for batch in train_dataloader:
            # Move data to the device
            inputs, labels = batch["image"].to(device), batch["mask"].to(device)
            
            # Zero the parameter gradients
            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(inputs)
            
            # Compute loss
            loss = criterion(outputs, labels)
            
            # Backward pass and optimize
            loss.backward()
            optimizer.step()
            
            # Save the loss and update progress bar
            train_losses.append(loss.item())
            pbar.update(1)
            pbar.set_postfix({"training_loss": loss.item()})
    
    # Compute average training loss for the epoch
    avg_train_loss = sum(train_losses) / len(train_losses)
    train_loss_history.append(avg_train_loss)
    
    # --------------------------
    # Validation Phase
    # --------------------------
    print("Validation in progress ...")
    model.eval()  # Set model to evaluation mode
    val_losses = []
    
    # Disable gradient computation for validation
    with torch.no_grad():
        with tqdm.tqdm(total=len(val_dataloader), desc=f"Validation Epoch {epoch + 1}/{num_epochs}", unit="batch") as pbar_val:
            for batch in val_dataloader:
                # Move data to the device
                inputs, labels = batch["image"].to(device), batch["mask"].to(device)
                
                # Forward pass
                outputs = model(inputs)
                
                # Compute loss
                loss = criterion(outputs, labels)
                val_losses.append(loss.item())
                
                pbar_val.update(1)
                pbar_val.set_postfix({"validation_loss": loss.item()})
    
    # Compute average validation loss for the epoch
    avg_val_loss = sum(val_losses) / len(val_losses)
    val_loss_history.append(avg_val_loss)
    
    print(f"Epoch {epoch + 1}/{num_epochs} - Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}")
    
    # --------------------------
    # Save Model Checkpoints
    # --------------------------
    # Save the last model after each epoch
    torch.save(model.state_dict(), "last_model.pth")
    
    # If the current validation loss is the best so far, save the model as the best model
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), "best_model.pth")
        print(f"Best model updated at epoch {epoch + 1} with validation loss {avg_val_loss:.4f}")
# Out:
# Epoch 1/1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1999/1999 [09:26<00:00,  3.53batch/s, training_loss=0.00187]
# Validation in progress ...
# Validation Epoch 1/1: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 502/502 [01:01<00:00,  8.20batch/s, validation_loss=0.000359]
# Epoch 1/1 - Training Loss: 0.0203, Validation Loss: 0.0048
# Best model updated at epoch 1 with validation loss 0.0048

# %%
# Create the test dataset and dataloader
dir_test = "data/test"

test_dataset = BratsDataset(
    dir_data=dir_test,
    list_slices=list_test_slices,  
    transform=None
)

test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
def compute_dice(outputs, targets, eps=1e-6):

    # Convert the logits to probability using sigmoid
    outputs = torch.sigmoid(outputs)
    
    # Convert probabilities to binary masks 
    outputs = (outputs > 0.5).float()
    targets = targets.float()
    
    # Compute intersection and union per sample
    intersection = (outputs * targets).sum(dim=(1, 2))
    union = outputs.sum(dim=(1, 2)) + targets.sum(dim=(1, 2))
    
    # Compute dice coefficient for each sample and then average over the batch
    dice = (2.0 * intersection + eps) / (union + eps)
    return dice.mean()

# %%
import pandas as pd

# %%
eps = 1e-6

model.eval()  
test_dice_scores = []

df_dice = pd.DataFrame(columns=["slice_name", "patient", "slice", "union", "intersection", "dice"])


with torch.no_grad():
    for batch in test_dataloader:

        slice_name = batch["slice_name"][0]
        inputs, labels = batch["image"].to(device), batch["mask"].to(device)
        
        # Forward pass
        outputs = model(inputs)
        # Squeeze out the channel dimension: now (B, H, W)
        outputs = outputs.squeeze(1)
        labels = labels.squeeze(1)

        # Convert the logits to probability using sigmoid
        outputs = torch.sigmoid(outputs)
        outputs = (outputs > 0.5).float()
        labels = labels.float()

        intersection = (outputs * labels).sum(dim=(1, 2))
        union = outputs.sum(dim=(1, 2)) + labels.sum(dim=(1, 2))

        intersection, union = intersection.item(), union.item()
        
        # Compute Dice coefficient for this batch (or single sample, if batch_size==1)
        dice = ((2.0 * intersection + eps) / (union + eps))

        print(fr"Slice name : {slice_name} -- GT volume: {labels.sum().item()}mm^3 -- Dice score: {dice * 100:.2f} %")
        df_dice.loc[len(df_dice)] = {
            "slice_name": slice_name, "patient": slice_name.split("_")[1], "slice": slice_name.split("_")[2],
            "union": union, "mask": mask, "dice": dice
        }

avg_test_dice = sum(test_dice_scores) / len(test_dice_scores)
print(f"\nmean Test Dice on all slices: {avg_test_dice:.4f}")
# Out:
# Slice name : patient_004_0000.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0001.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0002.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0003.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0004.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0005.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0006.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0007.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0008.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0009.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0010.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0011.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0012.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0013.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0014.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0015.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0016.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0017.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0018.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0019.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0020.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0021.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0022.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0023.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0024.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0025.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0026.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0027.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0028.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0029.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0030.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0031.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_004_0032.nii.gz -- GT volume: 2.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_004_0033.nii.gz -- GT volume: 143.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_004_0034.nii.gz -- GT volume: 340.0mm^3 -- Dice score: 13.70 %
# Slice name : patient_004_0035.nii.gz -- GT volume: 618.0mm^3 -- Dice score: 51.80 %
# Slice name : patient_004_0036.nii.gz -- GT volume: 784.0mm^3 -- Dice score: 77.09 %
# Slice name : patient_004_0037.nii.gz -- GT volume: 904.0mm^3 -- Dice score: 81.99 %
# Slice name : patient_004_0038.nii.gz -- GT volume: 972.0mm^3 -- Dice score: 82.58 %
# Slice name : patient_004_0039.nii.gz -- GT volume: 1023.0mm^3 -- Dice score: 75.45 %
# Slice name : patient_004_0040.nii.gz -- GT volume: 1021.0mm^3 -- Dice score: 75.29 %
# Slice name : patient_004_0041.nii.gz -- GT volume: 1005.0mm^3 -- Dice score: 73.06 %
# Slice name : patient_004_0042.nii.gz -- GT volume: 946.0mm^3 -- Dice score: 69.86 %
# Slice name : patient_004_0043.nii.gz -- GT volume: 878.0mm^3 -- Dice score: 75.32 %
# Slice name : patient_004_0044.nii.gz -- GT volume: 848.0mm^3 -- Dice score: 76.50 %
# Slice name : patient_004_0045.nii.gz -- GT volume: 817.0mm^3 -- Dice score: 72.43 %
# Slice name : patient_004_0046.nii.gz -- GT volume: 763.0mm^3 -- Dice score: 72.26 %
# Slice name : patient_004_0047.nii.gz -- GT volume: 746.0mm^3 -- Dice score: 74.88 %
# Slice name : patient_004_0048.nii.gz -- GT volume: 707.0mm^3 -- Dice score: 78.36 %
# Slice name : patient_004_0049.nii.gz -- GT volume: 754.0mm^3 -- Dice score: 76.37 %
# Slice name : patient_004_0050.nii.gz -- GT volume: 767.0mm^3 -- Dice score: 77.17 %
# Slice name : patient_004_0051.nii.gz -- GT volume: 847.0mm^3 -- Dice score: 78.19 %
# Slice name : patient_004_0052.nii.gz -- GT volume: 875.0mm^3 -- Dice score: 80.46 %
# Slice name : patient_004_0053.nii.gz -- GT volume: 836.0mm^3 -- Dice score: 74.02 %
# Slice name : patient_004_0054.nii.gz -- GT volume: 810.0mm^3 -- Dice score: 72.98 %
0mm^3 -- Dice score: 0.00 %
# Slice name : patient_006_0065.nii.gz -- GT volume: 161.0mm^3 -- Dice score: 65.95 %
# Slice name : patient_006_0066.nii.gz -- GT volume: 342.0mm^3 -- Dice score: 80.23 %
# Slice name : patient_006_0067.nii.gz -- GT volume: 464.0mm^3 -- Dice score: 82.48 %
# Slice name : patient_006_0068.nii.gz -- GT volume: 611.0mm^3 -- Dice score: 83.31 %
# Slice name : patient_006_0069.nii.gz -- GT volume: 688.0mm^3 -- Dice score: 85.18 %
# Slice name : patient_006_0070.nii.gz -- GT volume: 755.0mm^3 -- Dice score: 90.07 %
# Slice name : patient_006_0071.nii.gz -- GT volume: 811.0mm^3 -- Dice score: 93.37 %
# Slice name : patient_006_0072.nii.gz -- GT volume: 883.0mm^3 -- Dice score: 95.22 %
# Slice name : patient_006_0073.nii.gz -- GT volume: 889.0mm^3 -- Dice score: 94.99 %
# Slice name : patient_006_0074.nii.gz -- GT volume: 932.0mm^3 -- Dice score: 95.65 %
# Slice name : patient_006_0075.nii.gz -- GT volume: 964.0mm^3 -- Dice score: 95.49 %
# Slice name : patient_006_0076.nii.gz -- GT volume: 1009.0mm^3 -- Dice score: 94.82 %
# Slice name : patient_006_0077.nii.gz -- GT volume: 1055.0mm^3 -- Dice score: 94.16 %
# Slice name : patient_006_0078.nii.gz -- GT volume: 1073.0mm^3 -- Dice score: 94.60 %
# Slice name : patient_006_0079.nii.gz -- GT volume: 1046.0mm^3 -- Dice score: 95.24 %
# Slice name : patient_006_0080.nii.gz -- GT volume: 1010.0mm^3 -- Dice score: 95.80 %
# Slice name : patient_006_0081.nii.gz -- GT volume: 957.0mm^3 -- Dice score: 94.93 %
# Slice name : patient_006_0082.nii.gz -- GT volume: 870.0mm^3 -- Dice score: 91.92 %
# Slice name : patient_006_0083.nii.gz -- GT volume: 823.0mm^3 -- Dice score: 90.98 %
# Slice name : patient_006_0084.nii.gz -- GT volume: 716.0mm^3 -- Dice score: 88.37 %
# Slice name : patient_006_0085.nii.gz -- GT volume: 595.0mm^3 -- Dice score: 91.69 %
# Slice name : patient_006_0086.nii.gz -- GT volume: 592.0mm^3 -- Dice score: 91.58 %
# Slice name : patient_006_0087.nii.gz -- GT volume: 590.0mm^3 -- Dice score: 92.63 %
# Slice name : patient_006_0088.nii.gz -- GT volume: 559.0mm^3 -- Dice score: 92.39 %
# Slice name : patient_006_0089.nii.gz -- GT volume: 508.0mm^3 -- Dice score: 94.16 %
# Slice name : patient_006_0090.nii.gz -- GT volume: 501.0mm^3 -- Dice score: 92.62 %
# Slice name : patient_006_0091.nii.gz -- GT volume: 413.0mm^3 -- Dice score: 94.51 %
# Slice name : patient_006_0092.nii.gz -- GT volume: 354.0mm^3 -- Dice score: 94.95 %
# Slice name : patient_006_0093.nii.gz -- GT volume: 327.0mm^3 -- Dice score: 93.18 %
# Slice name : patient_006_0094.nii.gz -- GT volume: 250.0mm^3 -- Dice score: 93.75 %
# Slice name : patient_006_0095.nii.gz -- GT volume: 223.0mm^3 -- Dice score: 82.08 %
# Slice name : patient_006_0096.nii.gz -- GT volume: 132.0mm^3 -- Dice score: 82.70 %
# Slice name : patient_006_0097.nii.gz -- GT volume: 67.0mm^3 -- Dice score: 69.23 %
# Slice name : patient_006_0098.nii.gz -- GT volume: 32.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_006_0099.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0100.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0101.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0102.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0103.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0104.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0105.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0106.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0107.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0108.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0109.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0110.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0111.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0112.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0113.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0114.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0115.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0116.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0117.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0118.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0119.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0120.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0121.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0122.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0123.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0124.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0125.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0126.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0127.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0128.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0129.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0130.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0131.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0132.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0133.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0134.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0135.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0136.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0137.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0138.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0139.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0140.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0141.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0142.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0143.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0144.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0145.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0146.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0147.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_006_0148.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0000.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0001.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0002.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0003.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0004.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0005.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0006.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0007.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0008.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0009.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0010.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0011.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0012.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0013.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0014.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0015.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0016.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0017.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0018.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0019.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0020.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0021.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0022.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0023.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0024.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0025.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0026.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0027.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0028.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0029.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0030.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0031.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0032.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0033.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0034.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0035.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0036.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0037.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0038.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0039.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0040.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0041.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0042.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0043.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0044.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0045.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_010_0046.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0047.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0048.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0049.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0050.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0051.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0052.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0053.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0054.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0055.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0056.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0057.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0058.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0059.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0060.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0061.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0062.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0063.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0064.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0065.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0066.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0067.nii.gz -- GT volume: 41.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_010_0068.nii.gz -- GT volume: 70.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_010_0069.nii.gz -- GT volume: 102.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_010_0070.nii.gz -- GT volume: 109.0mm^3 -- Dice score: 51.32 %
# Slice name : patient_010_0071.nii.gz -- GT volume: 96.0mm^3 -- Dice score: 59.72 %
# Slice name : patient_010_0072.nii.gz -- GT volume: 71.0mm^3 -- Dice score: 22.50 %
# Slice name : patient_010_0073.nii.gz -- GT volume: 54.0mm^3 -- Dice score: 76.03 %
# Slice name : patient_010_0074.nii.gz -- GT volume: 137.0mm^3 -- Dice score: 64.89 %
# Slice name : patient_010_0075.nii.gz -- GT volume: 178.0mm^3 -- Dice score: 61.70 %
# Slice name : patient_010_0076.nii.gz -- GT volume: 211.0mm^3 -- Dice score: 61.52 %
# Slice name : patient_010_0077.nii.gz -- GT volume: 223.0mm^3 -- Dice score: 65.55 %
# Slice name : patient_010_0078.nii.gz -- GT volume: 227.0mm^3 -- Dice score: 68.99 %
# Slice name : patient_010_0079.nii.gz -- GT volume: 273.0mm^3 -- Dice score: 65.36 %
# Slice name : patient_010_0080.nii.gz -- GT volume: 318.0mm^3 -- Dice score: 62.77 %
# Slice name : patient_010_0081.nii.gz -- GT volume: 387.0mm^3 -- Dice score: 65.89 %
# Slice name : patient_010_0082.nii.gz -- GT volume: 427.0mm^3 -- Dice score: 69.76 %
# Slice name : patient_010_0083.nii.gz -- GT volume: 450.0mm^3 -- Dice score: 69.38 %
# Slice name : patient_010_0084.nii.gz -- GT volume: 443.0mm^3 -- Dice score: 71.05 %
# Slice name : patient_010_0085.nii.gz -- GT volume: 438.0mm^3 -- Dice score: 73.05 %
# Slice name : patient_010_0086.nii.gz -- GT volume: 460.0mm^3 -- Dice score: 76.27 %
# Slice name : patient_010_0087.nii.gz -- GT volume: 491.0mm^3 -- Dice score: 75.57 %
# Slice name : patient_010_0088.nii.gz -- GT volume: 536.0mm^3 -- Dice score: 80.89 %
# Slice name : patient_010_0089.nii.gz -- GT volume: 538.0mm^3 -- Dice score: 83.77 %
# Slice name : patient_010_0090.nii.gz -- GT volume: 538.0mm^3 -- Dice score: 86.39 %
# Slice name : patient_010_0091.nii.gz -- GT volume: 528.0mm^3 -- Dice score: 86.84 %
# Slice name : patient_010_0092.nii.gz -- GT volume: 528.0mm^3 -- Dice score: 88.09 %
# Slice name : patient_010_0093.nii.gz -- GT volume: 527.0mm^3 -- Dice score: 85.06 %
# Slice name : patient_010_0094.nii.gz -- GT volume: 528.0mm^3 -- Dice score: 81.80 %
# Slice name : patient_010_0095.nii.gz -- GT volume: 551.0mm^3 -- Dice score: 81.31 %
# Slice name : patient_010_0096.nii.gz -- GT volume: 528.0mm^3 -- Dice score: 81.96 %
# Slice name : patient_010_0097.nii.gz -- GT volume: 472.0mm^3 -- Dice score: 80.77 %
# Slice name : patient_010_0098.nii.gz -- GT volume: 453.0mm^3 -- Dice score: 82.00 %
# Slice name : patient_010_0099.nii.gz -- GT volume: 438.0mm^3 -- Dice score: 83.23 %
# Slice name : patient_010_0100.nii.gz -- GT volume: 436.0mm^3 -- Dice score: 86.83 %
# Slice name : patient_010_0101.nii.gz -- GT volume: 408.0mm^3 -- Dice score: 84.76 %
# Slice name : patient_010_0102.nii.gz -- GT volume: 376.0mm^3 -- Dice score: 85.85 %
# Slice name : patient_010_0103.nii.gz -- GT volume: 331.0mm^3 -- Dice score: 82.48 %
# Slice name : patient_010_0104.nii.gz -- GT volume: 285.0mm^3 -- Dice score: 79.16 %
# Slice name : patient_010_0105.nii.gz -- GT volume: 226.0mm^3 -- Dice score: 77.92 %
# Slice name : patient_010_0106.nii.gz -- GT volume: 179.0mm^3 -- Dice score: 79.50 %
# Slice name : patient_010_0107.nii.gz -- GT volume: 140.0mm^3 -- Dice score: 72.57 %
# Slice name : patient_010_0108.nii.gz -- GT volume: 87.0mm^3 -- Dice score: 57.38 %
# Slice name : patient_010_0109.nii.gz -- GT volume: 42.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_010_0110.nii.gz -- GT volume: 11.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_010_0111.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0112.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0113.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0114.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0115.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0116.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0117.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0118.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0119.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0120.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0121.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0122.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0123.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0124.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0125.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0126.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0127.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0128.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0129.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0130.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0131.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0132.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0133.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0134.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0135.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0136.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0137.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0138.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0139.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0140.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0141.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0142.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0143.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0144.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_010_0145.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0000.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0001.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0002.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0003.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0004.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0005.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0006.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0007.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0008.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0009.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0010.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0011.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0012.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0013.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0014.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0015.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0016.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0017.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0018.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0019.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0020.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0021.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0022.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0023.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0024.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0025.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0026.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0027.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0028.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0029.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0030.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0031.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0032.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0033.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0034.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0035.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0036.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0037.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0038.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0039.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0040.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0041.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0042.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0043.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0044.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0045.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0046.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0047.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0048.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0049.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0050.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0051.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0052.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_026_0053.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_026_0054.nii.gz -- GT volume: 31.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_026_0055.nii.gz -- GT volume: 97.0mm^3 -- Dice score: 75.95 %
# Slice name : patient_026_0056.nii.gz -- GT volume: 159.0mm^3 -- Dice score: 79.56 %
# Slice name : patient_026_0057.nii.gz -- GT volume: 216.0mm^3 -- Dice score: 86.22 %
# Slice name : patient_026_0058.nii.gz -- GT volume: 298.0mm^3 -- Dice score: 87.29 %
# Slice name : patient_026_0059.nii.gz -- GT volume: 352.0mm^3 -- Dice score: 86.12 %
# Slice name : patient_026_0060.nii.gz -- GT volume: 391.0mm^3 -- Dice score: 89.66 %
nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0028.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0029.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0030.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0031.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0032.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0033.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0034.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0035.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0036.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0037.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0038.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0039.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0040.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0041.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0042.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0043.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0044.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0045.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0046.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0047.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0048.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0049.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0050.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0051.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0052.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0053.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0054.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0055.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0056.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0057.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0058.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0059.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0060.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0061.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0062.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0063.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0064.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0065.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0066.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0067.nii.gz -- GT volume: 0.0mm^3 -- Dice score: 100.00 %
# Slice name : patient_046_0068.nii.gz -- GT volume: 6.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0069.nii.gz -- GT volume: 23.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0070.nii.gz -- GT volume: 90.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0071.nii.gz -- GT volume: 95.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0072.nii.gz -- GT volume: 78.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0073.nii.gz -- GT volume: 82.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0074.nii.gz -- GT volume: 71.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0075.nii.gz -- GT volume: 90.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0076.nii.gz -- GT volume: 131.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0077.nii.gz -- GT volume: 131.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0078.nii.gz -- GT volume: 137.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0079.nii.gz -- GT volume: 143.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0080.nii.gz -- GT volume: 188.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0081.nii.gz -- GT volume: 273.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0082.nii.gz -- GT volume: 244.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0083.nii.gz -- GT volume: 283.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0084.nii.gz -- GT volume: 332.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0085.nii.gz -- GT volume: 374.0mm^3 -- Dice score: 0.53 %
# Slice name : patient_046_0086.nii.gz -- GT volume: 391.0mm^3 -- Dice score: 5.96 %
# Slice name : patient_046_0087.nii.gz -- GT volume: 446.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0088.nii.gz -- GT volume: 442.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0089.nii.gz -- GT volume: 436.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0090.nii.gz -- GT volume: 466.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0091.nii.gz -- GT volume: 448.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0092.nii.gz -- GT volume: 490.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0093.nii.gz -- GT volume: 489.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0094.nii.gz -- GT volume: 475.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0095.nii.gz -- GT volume: 499.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0096.nii.gz -- GT volume: 533.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0097.nii.gz -- GT volume: 541.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0098.nii.gz -- GT volume: 592.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0099.nii.gz -- GT volume: 619.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0100.nii.gz -- GT volume: 648.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0101.nii.gz -- GT volume: 661.0mm^3 -- Dice score: 0.00 %
# Slice name : patient_046_0102.nii.gz -- GT volume: 722.0mm^3 -- Dice score: 6.43 %
# Slice name : patient_046_0103.nii.gz -- GT volume: 729.0mm^3 -- Dice score: 24.76 %
# Slice name : patient_046_0104.nii.gz -- GT volume: 714.0mm^3 -- Dice score: 17.39 %
# Slice name : patient_046_0105.nii.gz -- GT volume: 657.0mm^3 -- Dice score: 20.74 %
# Slice name : patient_046_0106.nii.gz -- GT volume: 686.0mm^3 -- Dice score: 22.51 %
# Slice name : patient_046_0107.nii.gz -- GT volume: 695.0mm^3 -- Dice score: 39.68 %
# Slice name : patient_046_0108.nii.gz -- GT volume: 652.0mm^3 -- Dice score: 43.83 %
# Slice name : patient_046_0109.nii.gz -- GT volume: 615.0mm^3 -- Dice score: 43.71 %
# Slice name : patient_046_0110.nii.gz -- GT volume: 604.0mm^3 -- Dice score: 44.33 %
# Slice name : patient_046_0111.nii.gz -- GT volume: 597.0mm^3 -- Dice score: 42.89 %
# Slice name : patient_046_0112.nii.gz -- GT volume: 619.0mm^3 -- Dice score: 42.29 %
# Slice name : patient_046_0113.nii.gz -- GT volume: 610.0mm^3 -- Dice score: 37.98 %
# Slice name : patient_046_0114.nii.gz -- GT volume: 622.0mm^3 -- Dice score: 38.86 %
# Slice name : patient_046_0115.nii.gz -- GT volume: 579.0mm^3 -- Dice score: 38.94 %
# Slice name : patient_046_0116.nii.gz -- GT volume: 555.0mm^3 -- Dice score: 36.66 %
# Slice name : patient_046_0117.nii.gz -- GT volume: 506.0mm^3 -- Dice score: 36.45 %
# Slice name : patient_046_0118.nii.gz -- GT volume: 469.0mm^3 -- Dice score: 37.59 %
# Slice name : patient_046_0119.nii.gz -- GT volume: 442.0mm^3 -- Dice score: 38.03 %
# Slice name : patient_046_0120.nii.gz -- GT volume: 440.0mm^3 -- Dice score: 31.09 %
# Slice name : patient_046_0121.nii.gz -- GT volume: 416.0mm^3 -- Dice score: 33.27 %
# Slice name : patient_046_0122.nii.gz -- GT volume: 411.0mm^3 -- Dice score: 35.20 %
# Slice name : patient_046_0123.nii.gz -- GT volume: 392.0mm^3 -- Dice score: 36.93 %
# Slice name : patient_046_0124.nii.gz -- GT volume: 376.0mm^3 -- Dice score: 36.52 %
# Slice name : patient_046_0125.nii.gz -- GT volume: 373.0mm^3 -- Dice score: 32.74 %
# Slice name : patient_046_0126.nii.gz -- GT volume: 353.0mm^3 -- Dice score: 25.25 %
# Slice name : patient_046_0127.nii.gz -- GT volume: 337.0mm^3 -- Dice score: 10.14 %
# Slice name : patient_046_0128.nii.gz -- GT volume: 361.0mm^3 -- Dice score: 16.28 %
# Slice name : patient_046_0129.nii.gz -- GT volume: 335.0mm^3 -- Dice score: 59.54 %
# Slice name : patient_046_0130.nii.gz -- GT volume: 327.0mm^3 -- Dice score: 63.33 %
# KeyboardInterrupt

# %%
# ------------------------------
# Visualize a few examples (only those with tumors)
# ------------------------------
num_examples = min(3, len(tumor_examples))

fig, axes = plt.subplots(num_examples, 3, figsize=(15, 5*num_examples))

# If only one example, ensure axes is 2D
if num_examples == 1:
    axes = np.expand_dims(axes, axis=0)
    
for i in range(num_examples):
    inp, pred, gt, dice = tumor_examples[i]
    # Assume batch size is >= 1; take the first sample in the batch.
    # Convert to numpy arrays for visualization.
    img = inp[0, 0, :, :].numpy()            # Original image
    gt_mask = gt[0].numpy()                   # Ground truth mask
    # Threshold prediction (it might still be probabilities)
    pred_mask = (pred[0] > 0.5).float().numpy()
    
    # Original image
    axes[i, 0].imshow(img.T, cmap="gray")
    axes[i, 0].set_title("Original Image")
    axes[i, 0].axis("off")
    
    # Ground truth overlay
    axes[i, 1].imshow(img.T, cmap="gray")
    axes[i, 1].imshow(gt_mask.T, cmap="jet", alpha=0.5)
    axes[i, 1].set_title("Ground Truth")
    axes[i, 1].axis("off")
    
    # Prediction overlay with Dice score
    axes[i, 2].imshow(img.T, cmap="gray")
    axes[i, 2].imshow(pred_mask.T, cmap="jet", alpha=0.5)
    axes[i, 2].set_title(fr"Prediction (Dice: {dice:.4f})")
    axes[i, 2].axis("off")
    
plt.tight_layout()
plt.show()

# %%
from scipy.spatial.distance import directed_hausdorff


def hausdorff_distance(outputs, targets):

    if torch.is_tensor(outputs):
        outputs = outputs.cpu().numpy()
    if torch.is_tensor(targets):
        targets = targets.cpu().numpy()
        
    # Get coordinates where mask==1
    coords_outputs = np.argwhere(outputs > 0)
    coords_targets = np.argwhere(targets > 0)
    
    # If one of the masks is empty, return nan (or a large number)
    if len(coords_outputs) == 0 or len(coords_targets) == 0:
        return np.nan
    
    d1 = directed_hausdorff(coords_outputs, coords_targets)[0]
    d2 = directed_hausdorff(coords_targets, coords_outputs)[0]
    return max(d1, d2)

# %%
# Load the trained model : 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.load_state_dict(torch.load("best_model_12022025.pth", map_location=device))
model.to(device)
model.eval()
# Out:
# UNet(
#   (enc1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (enc2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (enc3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (enc4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (enc5): Sequential(
#     (0): Conv2d(256, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (bottleneck): Sequential(
#     (0): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (up1): ConvTranspose2d(320, 256, kernel_size=(2, 2), stride=(2, 2))
#   (dec1): Sequential(
#     (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (up2): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#   (dec2): Sequential(
#     (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (up3): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#   (dec3): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (up4): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#   (dec4): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (out): Conv2d(32, 1, kernel_size=(1, 1), stride=(1, 1))
#   (maxpool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
model.eval()  
test_dice_scores = []
tumor_examples = []  # to save examples for visualization

with torch.no_grad():
    for inputs, labels in test_dataloader:

        inputs, labels = inputs.to(device), labels.to(device)
        
        # Forward pass
        outputs = model(inputs)
        # Squeeze out the channel dimension: now (B, H, W)
        outputs = outputs.squeeze(1)
        labels = labels.squeeze(1)
        
        # Check if the ground truth has any tumor pixels
        if labels.sum() > 0:
            # Compute Dice coefficient for this batch (or single sample, if batch_size==1)
            dice = compute_dice(outputs, labels)
            print(fr"GT volume: {labels.sum().item()} -- Dice score: {dice:.4f}")
            test_dice_scores.append(dice)
            
            # Save example for visualization (convert to cpu for plotting)
            # We'll save the first image in the batch
            tumor_examples.append((inputs.cpu(), outputs.cpu(), labels.cpu(), dice))
        else:
            print("No tumor in slice, skipping dice calculation.")

# Compute average Dice over all tumor-containing test slices
avg_test_dice = sum(test_dice_scores) / len(test_dice_scores)
print(f"\nTest Dice on tumor slices: {avg_test_dice:.4f}")
# Out:
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# GT volume: 2.0 -- Dice score: 0.0000
# GT volume: 143.0 -- Dice score: 0.0000
# GT volume: 340.0 -- Dice score: 0.0000
# GT volume: 618.0 -- Dice score: 0.8454
# GT volume: 784.0 -- Dice score: 0.9080
# GT volume: 904.0 -- Dice score: 0.9107
# GT volume: 972.0 -- Dice score: 0.9150
# GT volume: 1023.0 -- Dice score: 0.8776
# GT volume: 1021.0 -- Dice score: 0.8772
# GT volume: 1005.0 -- Dice score: 0.8733
# GT volume: 946.0 -- Dice score: 0.8725
# GT volume: 878.0 -- Dice score: 0.8828
# GT volume: 848.0 -- Dice score: 0.8823
# GT volume: 817.0 -- Dice score: 0.8563
# GT volume: 763.0 -- Dice score: 0.8420
# GT volume: 746.0 -- Dice score: 0.8777
# GT volume: 707.0 -- Dice score: 0.8856
# GT volume: 754.0 -- Dice score: 0.8738
# GT volume: 767.0 -- Dice score: 0.8938
# GT volume: 847.0 -- Dice score: 0.9020
# GT volume: 875.0 -- Dice score: 0.9181
# GT volume: 836.0 -- Dice score: 0.9017
# GT volume: 810.0 -- Dice score: 0.9089
# GT volume: 744.0 -- Dice score: 0.9124
# GT volume: 718.0 -- Dice score: 0.8997
# GT volume: 309.0 -- Dice score: 0.8474
# GT volume: 292.0 -- Dice score: 0.8328
# GT volume: 295.0 -- Dice score: 0.8441
# GT volume: 311.0 -- Dice score: 0.8698
# GT volume: 326.0 -- Dice score: 0.8882
# GT volume: 266.0 -- Dice score: 0.8622
# GT volume: 267.0 -- Dice score: 0.8376
# GT volume: 268.0 -- Dice score: 0.8566
# GT volume: 302.0 -- Dice score: 0.8304
# GT volume: 220.0 -- Dice score: 0.7754
# GT volume: 140.0 -- Dice score: 0.6040
# GT volume: 78.0 -- Dice score: 0.0000
# GT volume: 42.0 -- Dice score: 0.0000
# GT volume: 46.0 -- Dice score: 0.0000
# GT volume: 43.0 -- Dice score: 0.0000
# GT volume: 22.0 -- Dice score: 0.0000
# GT volume: 15.0 -- Dice score: 0.0000
# GT volume: 3.0 -- Dice score: 0.0000
# No tumor in slice, skipping dice calculation.
# GT volume: 2.0 -- Dice score: 0.0000
# GT volume: 17.0 -- Dice score: 0.0000
# GT volume: 54.0 -- Dice score: 0.8621
# GT volume: 106.0 -- Dice score: 0.9204
# GT volume: 119.0 -- Dice score: 0.8409
# GT volume: 119.0 -- Dice score: 0.8433
# GT volume: 128.0 -- Dice score: 0.7987
# GT volume: 146.0 -- Dice score: 0.8278
# GT volume: 173.0 -- Dice score: 0.8640
# GT volume: 193.0 -- Dice score: 0.8376
# GT volume: 209.0 -- Dice score: 0.8426
# GT volume: 205.0 -- Dice score: 0.8645
# GT volume: 204.0 -- Dice score: 0.8938
# GT volume: 196.0 -- Dice score: 0.9062
# GT volume: 163.0 -- Dice score: 0.8762
# GT volume: 130.0 -- Dice score: 0.8403
# GT volume: 73.0 -- Dice score: 0.7009
# GT volume: 11.0 -- Dice score: 0.0000
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
# No tumor in slice, skipping dice calculation.
#
# Test Dice on tumor slices: 0.6314

# %%
# ------------------------------
# Visualize a few examples (only those with tumors)
# ------------------------------
num_examples = min(3, len(tumor_examples))

fig, axes = plt.subplots(num_examples, 3, figsize=(15, 5*num_examples))

# If only one example, ensure axes is 2D
if num_examples == 1:
    axes = np.expand_dims(axes, axis=0)
    
for i in range(num_examples):
    inp, pred, gt, dice = tumor_examples[i]
    # Assume batch size is >= 1; take the first sample in the batch.
    # Convert to numpy arrays for visualization.
    img = inp[0, 0, :, :].numpy()            # Original image
    gt_mask = gt[0].numpy()                   # Ground truth mask
    # Threshold prediction (it might still be probabilities)
    pred_mask = (pred[0] > 0.5).float().numpy()
    
    # Original image
    axes[i, 0].imshow(img, cmap="gray")
    axes[i, 0].set_title("Original Image")
    axes[i, 0].axis("off")
    
    # Ground truth overlay
    axes[i, 1].imshow(img, cmap="gray")
    axes[i, 1].imshow(gt_mask, cmap="jet", alpha=0.5)
    axes[i, 1].set_title("Ground Truth")
    axes[i, 1].axis("off")
    
    # Prediction overlay with Dice score
    axes[i, 2].imshow(img, cmap="gray")
    axes[i, 2].imshow(pred_mask, cmap="jet", alpha=0.5)
    axes[i, 2].set_title(fr"Prediction (Dice: {dice:.4f})")
    axes[i, 2].axis("off")
    
plt.tight_layout()
plt.show()
